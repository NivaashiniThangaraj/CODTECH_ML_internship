# %%
from google.colab import files
uploaded = files.upload()  # Upload CODTECH_CNN_Image_Classification_Project.zip
# Out:
#      <input type="file" id="files-cea2a129-9413-4ff4-9fe7-98e1b8484194" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cea2a129-9413-4ff4-9fe7-98e1b8484194">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip CODTECH_CNN_Image_Classification_Project.zip
# Out:
# Archive:  CODTECH_CNN_Image_Classification_Project.zip
#   inflating: codtech_cnn_project/README.md
#   inflating: codtech_cnn_project/REPORT.md
#   inflating: codtech_cnn_project/requirements-pytorch.txt
#   inflating: codtech_cnn_project/requirements-tensorflow.txt
#   inflating: codtech_cnn_project/pytorch/model.py
#   inflating: codtech_cnn_project/pytorch/utils.py
#   inflating: codtech_cnn_project/pytorch/train.py
#   inflating: codtech_cnn_project/pytorch/evaluate.py
#   inflating: codtech_cnn_project/tensorflow/model.py
#   inflating: codtech_cnn_project/tensorflow/utils.py
#   inflating: codtech_cnn_project/tensorflow/train.py
#   inflating: codtech_cnn_project/tensorflow/evaluate.py

# %%
# !pip install -r codtech_cnn_project/requirements-pytorch.txt
# OR for TensorFlow
# !pip install -r CODTECH_CNN_Image_Classification_Project/requirements-tensorflow.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 57.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 30.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 34.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 3.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# %cd codtech_cnn_project/pytorch
# !python train.py --epochs 10 --batch-size 128 --lr 0.001 --outdir runs/exp1
# Out:
# /content/codtech_cnn_project/pytorch
# 100% 170M/170M [00:04<00:00, 34.4MB/s]
# Epoch 001: train_acc=0.4020 val_acc=0.4228
# Epoch 002: train_acc=0.5666 val_acc=0.5536
# Epoch 003: train_acc=0.6224 val_acc=0.6462
# Epoch 004: train_acc=0.6606 val_acc=0.6338
# Epoch 005: train_acc=0.6878 val_acc=0.6708
# Epoch 006: train_acc=0.7114 val_acc=0.7194
# Epoch 007: train_acc=0.7291 val_acc=0.7004
# Epoch 008: train_acc=0.7435 val_acc=0.7286
# Epoch 009: train_acc=0.7594 val_acc=0.7574
# Epoch 010: train_acc=0.7680 val_acc=0.7708
# Saved best model to: runs/exp1/best_model.pt
# Test Accuracy: 0.7767

# %%
# !python evaluate.py --weights runs/exp1/best_model.pt --outdir runs/exp1
# Out:
# Test Accuracy: 0.7767
# Saved evaluation artifacts to: runs/exp1
